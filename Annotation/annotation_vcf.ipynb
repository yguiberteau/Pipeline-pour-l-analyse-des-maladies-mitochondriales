# %%
import csv

# %% [markdown]
# Code de bourrin

# %%
#Ouverture du fichier VCF en mode lecture
with open('TSVC_variants_IonXpress_011.vcf','r') as vcf_file:
    #Creation et ouverture du fichier csv en mode écriture
    #Mettre chemin d'accès, de préférence avec dexu barres obliques pour éviter les porblèmes
    with open('C:\\Users\\Esther\\OneDrive\\Documents\\PROJET\\output_csv.csv','w',newline='') as csv_file :
        
        #Création d'un objet writer pour écrire dans un fichier CSV
        writer = csv.writer(csv_file)
        
        #Ecrire l'en-tête CSV
        writer.writerow(['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'AF', 'AO', 'DP', 'FAO', 'FDP', 'FDVR', 'FR', 'FRO', 'FSAF', 'FSAR', 'FSRF', 'FSRR', 'FWDB', 'FXX', 'HRUN', 'HS_ONLY', 'LEN', 'MLLD', 'OALT', 'OID', 'OMAPALT', 'OPOS', 'OREF', 'PB', 'PBP', 'QD', 'RBI', 'REFB', 'REVB', 'RO', 'SAF', 'SAR', 'SRF', 'SRR', 'SSEN', 'SSEP', 'SSSB', 'STB', 'STBP', 'TYPE', 'VARB', 'GT', 'GQ', 'DP', 'FDP', 'RO', 'FRO', 'AO', 'FAO', 'AF', 'SAR', 'SAF', 'SRF', 'SRR', 'FSAR', 'FSAF', 'FSRF', 'FSRR'])

        #Parcourir le fichier VCF ligne par ligne
        for line in vcf_file : 
            #Ignorer les lignes commentées
            if line.startswith('#'):
                continue
            #Diviser les lignes en colonnes en fonction des tabulations
            cols=line.strip().split('\t')
            # Extraire les informations nécéssaires
            CHROM = cols[0]
            POS = cols[1]
            ID = cols[2]
            REF = cols[3]
            ALT = cols[4]
            QUAL = cols[5]
            FILTERS = cols[6]
            
            INFO1 = cols[7]
            info1=INFO1.strip().split(';')
            #element d'information dans INFO1 
        
            AF = info1[0].split('=')[1]
            AO = info1[1].split('=')[1]
            DP = info1[2].split('=')[1]
            FAO = info1[3].split('=')[1]
            FDP = info1[4].split('=')[1]
            FDVR = info1[5].split('=')[1]
            FR = info1[6].split('=')[1]
            FRO = info1[7].split('=')[1]
            FSAF = info1[8].split('=')[1]
            FSAR = info1[9].split('=')[1]
            FSRF = info1[10].split('=')[1]
            FSRR = info1[11].split('=')[1]
            FWDB  = info1[12].split('=')[1]
            FXX  = info1[13].split('=')[1]
            HRUN  = info1[14].split('=')[1]
            HS_ONLY  = info1[15].split('=')[1]
            LEN = info1[16].split('=')[1]
            MLLD = info1[17].split('=')[1]
            OALT  = info1[18].split('=')[1]
            OID  = info1[19].split('=')[1]
            OMAPALT  = info1[20].split('=')[1]
            OPOS  = info1[21].split('=')[1]
            OREF  = info1[22].split('=')[1]
            PB  = info1[23].split('=')[1]
            PBP  = info1[24].split('=')[1]
            QD  = info1[25].split('=')[1]
            RBI = info1[26].split('=')[1]
            REFB = info1[27].split('=')[1]
            REVB = info1[28].split('=')[1]
            RO = info1[29].split('=')[1]
            SAF = info1[30].split('=')[1]
            SAR = info1[31].split('=')[1]
            SRF = info1[32].split('=')[1] 
            SRR = info1[33].split('=')[1] 
            SSEN = info1[34].split('=')[1] 
            SSEP = info1[35].split('=')[1] 
            SSSB = info1[36].split('=')[1] 
            STB = info1[37].split('=')[1] 
            STBP = info1[38].split('=')[1]
            TYPE = info1[39].split('=')[1] 
            VARB = info1[40].split('=')[1] 
            
            INFO2 = cols[8]
            INFO3 = cols[9]

            #Ecrire les informationsdans le fichier CSV
            writer.writerow([CHROM,POS,ID,REF,ALT,QUAL,FILTERS,AF,AO,DP,FAO,FDP,FDVR,FR,FRO,FSAF,FSAR,FSRF,FSRR,FWDB,FXX,HRUN,HS_ONLY,LEN,MLLD,OALT,OID,OMAPALT,OPOS,OREF,PB,PBP,QD,RBI,REFB,REVB,RO,SAF,SAR,SRF,SRR,SSEN,SSEP,SSSB,STB,STBP,TYPE,VARB,INFO2,INFO3])

# %% [markdown]
# Code avec liste

# %%
#Ouverture du fichier VCF en mode lecture
with open('TSVC_variants_IonXpress_011.vcf','r') as vcf_file:
    #Creation et ouverture du fichier csv en mode écriture
    #Mettre chemin d'accès, de préférence avec dexu barres obliques pour éviter les porblèmes
    with open('C:\\Users\\Esther\\OneDrive\\Documents\\PROJET\\output_csv.csv','w',newline='') as csv_file :
        
        #Création d'un objet writer pour écrire dans un fichier CSV
        writer = csv.writer(csv_file)
        
        #Ecrire l'en-tête CSV
        writer.writerow(['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'AF', 'AO', 'DP', 'FAO', 'FDP', 'FDVR', 'FR', 'FRO', 'FSAF', 'FSAR', 'FSRF', 'FSRR', 'FWDB', 'FXX', 'HRUN', 'HS_ONLY', 'LEN', 'MLLD', 'OALT', 'OID', 'OMAPALT', 'OPOS', 'OREF', 'PB', 'PBP', 'QD', 'RBI', 'REFB', 'REVB', 'RO', 'SAF', 'SAR', 'SRF', 'SRR', 'SSEN', 'SSEP', 'SSSB', 'STB', 'STBP', 'TYPE', 'VARB', 'GT', 'GQ', 'DP', 'FDP', 'RO', 'FRO', 'AO', 'FAO', 'AF', 'SAR', 'SAF', 'SRF', 'SRR', 'FSAR', 'FSAF', 'FSRF', 'FSRR'])

        #Parcourir le fichier VCF ligne par ligne
        for line in vcf_file : 
            #Ignorer les lignes commentées
            if line.startswith('#'):
                continue
            #Diviser les lignes en colonnes en fonction des tabulations
            cols=line.strip().split('\t')
            # Extraire les informations nécéssaires
            
            data_col = []
            for i in range(len(cols)):
                if i != 7:
                    data_col.append(cols[i])
            informations = cols[7].strip().split(';')
            for i in range(len(informations)):
                data_col.append(informations[i].split("=")[1])
            
            writer.writerow(data_col)

# %% [markdown]
# Code avec dictionnaire

# %%
#Ouverture du fichier VCF en mode lecture
with open('TSVC_variants_IonXpress_011.vcf','r') as vcf_file:
    #Creation et ouverture du fichier csv en mode écriture
    #Mettre chemin d'accès, de préférence avec dexu barres obliques pour éviter les porblèmes
    with open('C:\\Users\\Esther\\OneDrive\\Documents\\PROJET\\output_csv.csv','w',newline='') as csv_file :
        
        #Création d'un objet writer pour écrire dans un fichier CSV
        writer = csv.writer(csv_file)
        
        #Ecrire l'en-tête CSV
        writer.writerow(['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'AF', 'AO', 'DP', 'FAO', 'FDP', 'FDVR', 'FR', 'FRO', 'FSAF', 'FSAR', 'FSRF', 'FSRR', 'FWDB', 'FXX', 'HRUN', 'HS_ONLY', 'LEN', 'MLLD', 'OALT', 'OID', 'OMAPALT', 'OPOS', 'OREF', 'PB', 'PBP', 'QD', 'RBI', 'REFB', 'REVB', 'RO', 'SAF', 'SAR', 'SRF', 'SRR', 'SSEN', 'SSEP', 'SSSB', 'STB', 'STBP', 'TYPE', 'VARB', 'GT', 'GQ', 'DP', 'FDP', 'RO', 'FRO', 'AO', 'FAO', 'AF', 'SAR', 'SAF', 'SRF', 'SRR', 'FSAR', 'FSAF', 'FSRF', 'FSRR'])

        #Parcourir le fichier VCF ligne par ligne
        for line in vcf_file : 
            #Ignorer les lignes commentées
            if line.startswith('#'):
                continue
            #Diviser les lignes en colonnes en fonction des tabulations
            cols=line.strip().split('\t')

            data_dic = {}
            keys = ['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'AF', 'AO', 'DP', 'FAO', 'FDP', 'FDVR', 'FR', 'FRO', 'FSAF',
                    'FSAR', 'FSRF', 'FSRR', 'FWDB', 'FXX', 'HRUN', 'HS_ONLY', 'LEN', 'MLLD', 'OALT', 'OID', 'OMAPALT', 'OPOS', 'OREF',
                    'PB', 'PBP', 'QD', 'RBI', 'REFB', 'REVB', 'RO', 'SAF', 'SAR', 'SRF', 'SRR', 'SSEN', 'SSEP', 'SSSB', 'STB', 'STBP',
                    'TYPE', 'VARB', 'GT', 'GQ', 'DP', 'FDP', 'RO', 'FRO', 'AO', 'FAO', 'AF', 'SAR', 'SAF', 'SRF', 'SRR', 'FSAR', 'FSAF', 'FSRF', 'FSRR']
            for key, i in zip(keys, range(len(cols))):
                pass
